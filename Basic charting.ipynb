# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot([1,2,3],[2,5,7])
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot([1,2,3],[2,5,7])
plt.title("Chandan's data")
plt.ylabel("Y - Axis")
plt.xlabel("X - Axis")
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import style

style.use('ggplot')
x= [1,5,4]
y = [23,45,89]
x2= [3,7,3]
y2 = [5,8,9]
plt.plot(x,y, label = 'first', linewidth = 2)
plt.plot(x2,y2, label = 'second',linewidth = 4)
plt.legend()
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import style

style.use('ggplot')
x= [1,5,4]
y = [23,45,89]
x2= [3,7,3]
y2 = [5,8,9]
plt.title("Scatter view")
plt.scatter(x,y, label = 'first', linewidth = 2)
plt.plot(x2,y2, label = 'second',linewidth = 4)
plt.legend()
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import style

style.use('ggplot')
x= [1,5,4]
y = [23,45,89]
x2= [3,7,3]
y2 = [5,8,9]
plt.title("Histogram view")
plt.scatter(x,y, label = 'first', linewidth = 2)
plt.hist(x2, label = 'second',linewidth = 4)
plt.legend()
plt.show()
